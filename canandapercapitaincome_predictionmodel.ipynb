# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/canada_per_capita_income.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year, df['per capita income (US$)'], color='blue', marker='+',s=50)
plt.show()  # Display the plot

# %%
new_df = df.drop('per capita income (US$)', axis=1)
new_df
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
Income=df[['per capita income (US$)']]
Income
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,Income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])

# %%
Year_df = pd.read_csv('/content/year.csv')

# %%
year_df.rename(columns={'Year': 'year'}, inplace=True)
p = reg.predict(year_df)

# %%
p=reg.predict(year_df)
p
# Out:
# array([[37974.83379353],
#        [38803.29886875],
#        [39631.76394397],
#        [40460.22901919],
#        [41288.69409442],
#        [42117.15916964],
#        [42945.62424486],
#        [43774.08932009],
#        [44602.55439531],
#        [45431.01947053],
#        [46259.48454575],
#        [47087.94962098],
#        [47916.4146962 ],
#        [48744.87977142],
#        [49573.34484664],
#        [50401.80992187],
#        [51230.27499709],
#        [52058.74007231],
#        [52887.20514754],
#        [53715.67022276],
#        [54544.13529798],
#        [55372.6003732 ],
#        [56201.06544843],
#        [57029.53052365],
#        [57857.99559887],
#        [58686.46067409],
#        [59514.92574932],
#        [60343.39082454],
#        [61171.85589976],
#        [62000.32097499],
#        [62828.78605021],
#        [63657.25112543]])

# %%
Year_df['Per capita Income']=p
Year_df
# Out:
#     Year  Per capita Income
# 0   2016       37974.833794
# 1   2017       38803.298869
# 2   2018       39631.763944
# 3   2019       40460.229019
# 4   2020       41288.694094
# 5   2021       42117.159170
# 6   2022       42945.624245
# 7   2023       43774.089320
# 8   2024       44602.554395
# 9   2025       45431.019471
# 10  2026       46259.484546
# 11  2027       47087.949621
# 12  2028       47916.414696
# 13  2029       48744.879771
# 14  2030       49573.344847
# 15  2031       50401.809922
# 16  2032       51230.274997
# 17  2033       52058.740072
# 18  2034       52887.205148
# 19  2035       53715.670223
# 20  2036       54544.135298
# 21  2037       55372.600373
# 22  2038       56201.065448
# 23  2039       57029.530524
# 24  2040       57857.995599
# 25  2041       58686.460674
# 26  2042       59514.925749
# 27  2043       60343.390825
# 28  2044       61171.855900
# 29  2045       62000.320975
# 30  2046       62828.786050
# 31  2047       63657.251125

# %%
Year_df.to_csv("Result.csv")
